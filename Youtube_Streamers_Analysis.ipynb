# %% [markdown]
# <a href="https://colab.research.google.com/github/neeraj2082/YoutubeStreamerAnalysis/blob/main/Youtube_Streamers_Analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing of libraries
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# 1.DATA EXPLORATION
#
#
# 1. Start by exploring the dataset to understand its structure and identify key variables.
#
#
# 2. Check for missing data and outliers.

# %%
import pandas as pd
path="/content/youtubers_df.csv"
df= pd.read_csv(path)
df.head(5) #shows the first five rows
# Out:
#    Rank       Username           Categories   Suscribers         Country  \
# 0     1        tseries       Música y baile  249500000.0           India
# 1     2        MrBeast   Videojuegos, Humor  183500000.0  Estados Unidos
# 2     3      CoComelon            Educación  165500000.0         Unknown
# 3     4       SETIndia                  NaN  162600000.0           India
# 4     5  KidsDianaShow  Animación, Juguetes  113500000.0         Unknown
#
#         Visits      Likes  Comments  \
# 0      86200.0     2700.0      78.0
# 1  117400000.0  5300000.0   18500.0
# 2    7000000.0    24700.0       0.0
# 3      15600.0      166.0       9.0
# 4    3900000.0    12400.0       0.0
#
#                                                Links
# 0  http://youtube.com/channel/UCq-Fj5jknLsUf-MWSy...
# 1  http://youtube.com/channel/UCX6OQ3DkcsbYNE6H8u...
# 2  http://youtube.com/channel/UCbCmjCuTUZos6Inko4...
# 3  http://youtube.com/channel/UCpEhnqL0y41EpW2TvW...
# ...

# %%
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia                  NaN  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang                  NaN   11700000.0
# 996   997            Adaahqueen                  NaN   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex                  NaN   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
#shows its mean,median,..
df.describe()
# Out:
#               Rank    Suscribers        Visits         Likes       Comments
# count  1000.000000  1.000000e+03  1.000000e+03  1.000000e+03    1000.000000
# mean    500.500000  2.189440e+07  1.209446e+06  5.363259e+04    1288.768000
# std     288.819436  1.682775e+07  5.229942e+06  2.580457e+05    6778.188308
# min       1.000000  1.170000e+07  0.000000e+00  0.000000e+00       0.000000
# 25%     250.750000  1.380000e+07  3.197500e+04  4.717500e+02       2.000000
# 50%     500.500000  1.675000e+07  1.744500e+05  3.500000e+03      67.000000
# 75%     750.250000  2.370000e+07  8.654750e+05  2.865000e+04     472.000000
# max    1000.000000  2.495000e+08  1.174000e+08  5.300000e+06  154000.000000

# %%
#shows the rows and columns
df.shape
# Out:
# (1000, 9)

# %%
#shows detail information about the dataset along with datatype
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Rank        1000 non-null   int64
#  1   Username    1000 non-null   object
#  2   Categories  694 non-null    object
#  3   Suscribers  1000 non-null   float64
#  4   Country     1000 non-null   object
#  5   Visits      1000 non-null   float64
#  6   Likes       1000 non-null   float64
#  7   Comments    1000 non-null   float64
#  8   Links       1000 non-null   object
# dtypes: float64(4), int64(1), object(4)
# memory usage: 70.4+ KB

# %%
#Shows the columns names in the dataset
df.columns
# Out:
# Index(['Rank', 'Username', 'Categories', 'Suscribers', 'Country', 'Visits',
#        'Likes', 'Comments', 'Links'],
#       dtype='object')

# %%
#counts the number of unique datas
df.nunique()
# Out:
# Rank          1000
# Username       994
# Categories      45
# Suscribers     274
# Country         29
# Visits         713
# Likes          648
# Comments       389
# Links          994
# dtype: int64

# %%
#finding of missing values
df.isnull().sum()
# Out:
# Rank            0
# Username        0
# Categories    306
# Suscribers      0
# Country         0
# Visits          0
# Likes           0
# Comments        0
# Links           0
# dtype: int64

# %%
#Return the missing values as "Not Applicable"
df.fillna('Not Applicable',inplace=True)
df
# Out:
#      Rank              Username           Categories   Suscribers  \
# 0       1               tseries       Música y baile  249500000.0
# 1       2               MrBeast   Videojuegos, Humor  183500000.0
# 2       3             CoComelon            Educación  165500000.0
# 3       4              SETIndia       Not Applicable  162600000.0
# 4       5         KidsDianaShow  Animación, Juguetes  113500000.0
# ..    ...                   ...                  ...          ...
# 995   996          hamzymukbang       Not Applicable   11700000.0
# 996   997            Adaahqueen       Not Applicable   11700000.0
# 997   998  LittleAngelIndonesia       Música y baile   11700000.0
# 998   999          PenMultiplex       Not Applicable   11700000.0
# 999  1000         OneindiaHindi  Noticias y Política   11700000.0
#
#             Country       Visits      Likes  Comments  \
# 0             India      86200.0     2700.0      78.0
# 1    Estados Unidos  117400000.0  5300000.0   18500.0
# ...

# %%
#finding of missing values
df.isnull().sum()
# Out:
# Rank          0
# Username      0
# Categories    0
# Suscribers    0
# Country       0
# Visits        0
# Likes         0
# Comments      0
# Links         0
# dtype: int64

# %%
#identifying of the unique records
df["Country"].unique()
# Out:
# array(['India', 'Estados Unidos', 'Unknown', 'Brasil', 'México', 'Rusia',
#        'Pakistán', 'Filipinas', 'Indonesia', 'Tailandia', 'Francia',
#        'Colombia', 'Iraq', 'Japón', 'Ecuador', 'Argentina', 'Turquía',
#        'Arabia Saudita', 'El Salvador', 'Bangladesh', 'Reino Unido',
#        'Argelia', 'España', 'Perú', 'Egipto', 'Jordania', 'Marruecos',
#        'Singapur', 'Somalia'], dtype=object)

# %%
#checking the presence of duplicates
df.duplicated().sum()
# Out:
# 0

# %%
#Renaming of the column name
df.rename(columns={"Suscribers":"Subscribers"},inplace=True)
df.columns
# Out:
# Index(['Rank', 'Username', 'Categories', 'Subscribers', 'Country', 'Visits',
#        'Likes', 'Comments', 'Links'],
#       dtype='object')

# %% [markdown]
# 2.Trend Analysis
#
#
# 1. Identify trends among the top YouTube streamers. Which categories are the most popular?
#
#
# 2. Is there a correlation between the number of subscribers and the number of likes or comments?

# %%
#Finding of the popular categories
counts_category=df["Categories"].value_counts()
plt.figure(figsize=(18,10))
plt.title("List of Categories")
plt.xlabel("Categories")
plt.ylabel("Streamers")
plt.xticks(rotation=90)
sns.barplot(x=counts_category.index,y=counts_category.values,color="brown");

# %%
#Finding of correlation between Subscribers and Likes
column1 = 'Subscribers'
column2 = 'Likes'
correlation = df[column1].corr(df[column2])
print("Correlation between Subscribers and Likes:",correlation)
# Out:
# Correlation between Subscribers and Likes: 0.21163868368008265

# %%
#Heatmap for the correlation of Subscribers and Likes
column1 = 'Subscribers'
column2 = 'Likes'

correlation_matrix = df[[column1, column2]].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='viridis', fmt=".2f")
plt.title('Correlation Heatmap for Subscribers and Likes')
plt.show()

# %%
#Finding of correlation between Subscribers and Comments
column1 = 'Subscribers'
column2 = 'Comments'
correlation = df[column1].corr(df[column2])
print("Correlation between Subscribers and Comments:",correlation)
#Heatmap for the correlation of Subscribers and Comments
correlation_matrix = df[[column1, column2]].corr()
plt.figure(figsize=(8,6))
sns.heatmap(correlation_matrix, annot=True, cmap='PuRd', fmt=".2f")
plt.title('Correlation Heatmap for Subscribers and Comments')
plt.show()
# Out:
# Correlation between Subscribers and Comments: 0.03634982616105402

# %%
#Scatter plot for Likes and Comments
sns.set_style("darkgrid")
plt.figure(figsize=(8,5))
sns.scatterplot(data=df, x='Likes', y='Comments',color='brown')
plt.title('Scatter Plot of Likes vs Comments')
plt.xlabel('Likes')
plt.ylabel('Comments')
plt.show();

# %%
#Cat plot for Subscribers and Comments
plt.figure(figsize=(8,5))
sns.catplot(data=df, x='Subscribers', y='Comments',kind='point',color='brown')
plt.title('Cat Plot of Subscribers vs Comments')
plt.xlabel('Subscribers')
plt.ylabel('Comments')
plt.show();

# %% [markdown]
# 3.Audience Study
#
#
# 1. Analyze the distribution of streamers ' audiences by country. Are there regional preferences for
# specific content categories?

# %%
# Analyze the distribution of streamers' audiences by country
country_counts = df['Country'].value_counts()
plt.plot(country_counts.index, country_counts.values, 'o-b')
plt.title("Distribution of streamers based on country")
plt.xlabel("Countries")
plt.ylabel("Streamers")
plt.xticks(rotation=90)
plt.show()

# %%
counts_category=df.groupby(['Country','Categories'])['Username'].count().unstack().fillna(0)
counts_category
# Out:
# Categories      ASMR  ASMR, Comida y bebida  Animación  Animación, Humor  \
# Country
# Arabia Saudita   0.0                    0.0        0.0               0.0
# Argelia          0.0                    0.0        0.0               0.0
# Argentina        0.0                    0.0        1.0               0.0
# Bangladesh       0.0                    0.0        0.0               0.0
# Brasil           0.0                    0.0        3.0               2.0
# Colombia         0.0                    0.0        0.0               2.0
# Ecuador          0.0                    0.0        0.0               0.0
# Egipto           0.0                    0.0        0.0               0.0
# El Salvador      0.0                    0.0        0.0               0.0
# España           0.0                    0.0        0.0               0.0
# Estados Unidos   1.0                    1.0        4.0              17.0
# Filipinas        0.0                    0.0        0.0               0.0
# ...

# %% [markdown]
# 4. Performance Metrics
#
#
# 1. Calculate and visualize the average number of subscribers, visits, likes, and comments.
# 2. Are there patterns or anomalies in these metrics?

# %%
#Showing of the top10 subscribers along with their username (Tseries-1st)
X=df["Username"].head(10)
Y=df["Subscribers"].tail(10)

# %%
#Piechart of showing the top10 subscribers
username=X
subscribers=Y
plt.pie(subscribers,labels=username,startangle=360)
plt.show();

# %%
#Finding of the averages
avg_subscribers=df['Subscribers'].mean()
avg_likes=df['Likes'].mean()
avg_comments=df['Comments'].mean()
avg_visits=df['Visits'].mean()

print("Average Subscribers",avg_subscribers)
print("Average Likes",avg_likes)
print("Average Comments",avg_comments)
print("Average visits",avg_visits)
# Out:
# Average Subscribers 21894400.0
# Average Likes 53632.592
# Average Comments 1288.768
# Average visits 1209446.3155

# %%
#Linechart for the number of subscribers, likes ,commetns and visits
plt.figure(figsize=(12,8))
#Subscribers
plt.subplot(2,2,1)
plt.plot(df['Subscribers'],color='red')
plt.title("Subscribers")
#Likes
plt.subplot(2, 2, 2)
plt.plot( df['Likes'], color='black')
plt.title('Likes')
#Comments
plt.subplot(2,2,3)
plt.plot(df['Comments'],color='Gray')
plt.title("Comments")
#Visits
plt.subplot(2,2,4)
plt.plot(df['Visits'],color='brown')
plt.title("Visits");

# %%
#Finding of the average metrics of the dataset
metrics=['Subscribers','Likes','Comments','Visits']
average=[avg_subscribers,avg_likes,avg_comments,avg_visits]
plt.figure(figsize=(12,8))
plt.plot(metrics,average,'o-y')
sns.barplot(x=metrics, y=average, color='brown')
plt.xlabel(metrics)
plt.ylabel(average)
plt.title("Average Performance Metrics")
plt.xticks(rotation=360)
plt.show();

# %% [markdown]
# 5.Content Categories
#
#
# 1. Explore the distribution of content categories. Which categories have the highest number of streamers?
#
#
# 2. Are there specific categories with exceptional performance metrics?

# %%
#Showing of the number of streamers based on categories
category_counts=df['Categories'].value_counts()
plt.figure(figsize=(20,8))
sns.barplot(x=category_counts.index,y=category_counts.values,color='brown')
plt.plot(category_counts.index, category_counts.values,'o--b')
plt.title("No of streamers based on content categories")
plt.xlabel("Content Categories")
plt.ylabel("No of streamers")
plt.xticks(rotation=90)
plt.show();

# %%
#Showing of the category with highest number of streamers
#idxmax()-->shows the highest category rank
category_counts=df['Categories'].value_counts().idxmax()
print("Category with highest number of streamers:",category_counts)
# Out:
# Category with highest number of streamers: Not Applicable

# %%
#Categories with exceptional performance
category_counts = df['Categories'].value_counts()
threshold = 40 #filtering of datas which is lower than 40
exceptional_categories = category_counts[category_counts > threshold]
print("Categories with Exceptional Performance:")
print(exceptional_categories)
# Out:
# Categories with Exceptional Performance:
# Categories
# Not Applicable               306
# Música y baile               160
# Películas, Animación          61
# Música y baile, Películas     41
# Name: count, dtype: int64

# %%
#Barplot for Categories with Exceptional Performance
plt.figure(figsize=(8, 4))
plt.plot(exceptional_categories.index,exceptional_categories.values,'o--r')
sns.barplot(x=exceptional_categories.index, y=exceptional_categories.values)
plt.title('Categories with Exceptional Performance')
plt.xlabel('Categories')
plt.ylabel('Subscribers Count')
plt.show()

# %% [markdown]
# 6.Brands and Collaboration
#
# 1. Analyze whether streamers with high performance metrics receive more brand collaborations and marketing campaigns.

# %%
brands = df[['Categories','Comments', 'Likes', 'Visits']].sort_values(by = 'Likes' ,ascending=False)
top_brands = brands.head(5)
top_brands
# Out:
#              Categories  Comments      Likes       Visits
# 1    Videojuegos, Humor   18500.0  5300000.0  117400000.0
# 136       Vlogs diarios   11600.0  5000000.0   83100000.0
# 153    Animación, Humor   82800.0  1700000.0   52700000.0
# 341               Humor   38000.0  1400000.0   11100000.0
# 734      Not Applicable   15800.0  1200000.0   11700000.0

# %%
#Barplot for top 5 influenced brands
sns.barplot(data=top_brands, x='Categories', y='Likes',color='brown')
plt.title("Top 5 most Influenced Brands ")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

# %% [markdown]
# 7.Benchmarking
#
#
# 1. Identify streamers with above-average performance in terms of subscribers, visits, likes, and comments.
# 2. Who are the top-performing content creators?

# %%
#Streamers with above-average performance
df['Above_avgSubscribers'] = df['Subscribers'] > avg_subscribers
df['Above_avgVisits'] = df['Visits'] > avg_visits
df['Above_avgLikes'] = df['Likes'] > avg_likes
df['Above_avgComments'] = df['Comments'] > avg_comments
top_performing_streamers = df[df['Above_avgSubscribers'] & df['Above_avgVisits'] & df['Above_avgLikes'] & df['Above_avgComments']]
print(top_performing_streamers)
# Out:
#      Rank               Username                     Categories  Subscribers  \
# 1       2                MrBeast             Videojuegos, Humor  183500000.0
# 5       6              PewDiePie         Películas, Videojuegos  111500000.0
# 26     27            dudeperfect                    Videojuegos   59700000.0
# 34     35            TaylorSwift                 Música y baile   54100000.0
# 39     40            JuegaGerman           Películas, Animación   48600000.0
# 43     44               A4a4a4a4               Animación, Humor   47300000.0
# 58     59              Mikecrack           Películas, Animación   43400000.0
# 62     63         KimberlyLoaiza                 Música y baile   42100000.0
# 64     65        luisitocomunica                 Not Applicable   41100000.0
# 70     71            JessNoLimit           Películas, Animación   39600000.0
# 96     97         TotalGaming093         Películas, Videojuegos   36300000.0
# ...

# %%
#Top visiters of the channel
visit = df[['Username', 'Visits', 'Subscribers']].sort_values(by = 'Visits' ,ascending=False)
top_visit = visit.head(10)
print(top_visit)
# Out:
#                   Username       Visits  Subscribers
# 1                  MrBeast  117400000.0  183500000.0
# 136               MrBeast2   83100000.0   31300000.0
# 153              DaFuqBoom   52700000.0   29800000.0
# 488      BeastPhilanthropy   21500000.0   16900000.0
# 288  VillageCookingChannel   21500000.0   22500000.0
# 390            jaanvipatel   19100000.0   19100000.0
# 586               _vector_   15400000.0   15400000.0
# 958                dojacat   13600000.0   11900000.0
# 300           alfredolarin   12900000.0   21900000.0
# 805                NickPro   12200000.0   13200000.0

# %%
#Barplot showing of the top10 content creators
plt.figure(figsize=(10,5))
sns.barplot(data=top_visit, x='Visits', y='Username', color='brown')
plt.title("Top 10 content creators")
plt.xlabel("Visits")
plt.ylabel('Username')
plt.tight_layout()
plt.show()
